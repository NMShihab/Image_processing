# %%
from PIL import Image
from skimage import data, color,io
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
img = io.imread("natural-beauty-bangladesh.jpg")

# %%
img.shape
# Out:
# (607, 910, 3)

# %%
gray_scaled_img = color.rgb2gray(img)

# %%
np.shape(gray_scaled_img)
# Out:
# (607, 910)

# %%
def show_image(image, title='Image',cmap_type='gray'):
    plt.imshow(image, cmap=cmap_type)
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
show_image(img)

# %%
show_image(gray_scaled_img)
